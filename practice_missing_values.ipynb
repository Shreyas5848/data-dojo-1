# %% [markdown]
# # Practice Session: Customer Data Cleaning Basics
#
# ## Concept: Missing Values
#
# **Your Task:** Use the techniques you've learned to work with the dataset for this project. The dataset is located at `datasets/ecommerce/customers_messy.csv`.

# %%
import pandas as pd
dataset_path = 'datasets/ecommerce/customers_messy.csv'
df = pd.read_csv(dataset_path)
print('Dataset loaded successfully!')
df.head()

# %% [markdown]
# ### Your Workspace
#
# Use the cell below to write your Python code to practice the concept.

# %%
# Your code here...

# %% [markdown]
# ### Validation
#
# Run the cell below to check your work (Note: this is a placeholder for a real validation step).

# %%
# Example validation: check if missing values have been handled
if df.isnull().sum().sum() == 0:
    print('Great job! No missing values found.')
else:
    print('Looks like there are still some missing values. Keep going!')
